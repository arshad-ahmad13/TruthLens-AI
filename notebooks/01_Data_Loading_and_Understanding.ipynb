# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
df = pd.read_csv("../data/raw/fake_and_real_news_dataset.csv")

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 4594
# Columns : 4

# %%
df.columns
# Out:
# Index(['idd', 'title', 'text', 'label'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4594 entries, 0 to 4593
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   idd     4594 non-null   object
#  1   title   4593 non-null   object
#  2   text    4594 non-null   object
#  3   label   4594 non-null   object
# dtypes: object(4)
# memory usage: 143.7+ KB

# %%
df.dtypes
# Out:
# idd      object
# title    object
# text     object
# label    object
# dtype: object

# %%
df.describe()
# Out:
#                idd                    title  \
# count         4594                     4593
# unique        4594                     4537
# top     Fq+C96tcx+  Log In - New York Times
# freq             1                        5
#
#                                                      text label
# count                                                4594  4594
# unique                                               4409     2
# top     Killing Obama administration rules, dismantlin...  REAL
# freq                                                   37  2297

# %%
df.isnull().sum()
# Out:
# idd      0
# title    1
# text     0
# label    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
print("Duplicate Rows :", df.duplicated().sum())
# Out:
# Duplicate Rows : 0

# %%
df["label"].unique()
# Out:
# array(['REAL', 'FAKE'], dtype=object)

# %%
df["label"].value_counts()
# Out:
# label
# FAKE    2297
# REAL    2296
# Name: count, dtype: int64

# %%
df["label"].value_counts(normalize=True)*100
# Out:
# label
# FAKE    50.010886
# REAL    49.989114
# Name: proportion, dtype: float64

# %%
df.sample(5)
# Out:
#              idd                                              title  \
# 2592  6WxRN&5%6C   Vladimir Putin – Straight From The Horse’s Mouth
# 2839  Kb6&Oe@W7G              WWN Guide To Preventing World War III
# 2302  uhkf*Ev@_W  Russia prevented Spain from diplomatical confl...
# 3496  _Q+qx2i7v3  Syrian War Report – November 4, 2016: Govt For...
# 2248  Vjfl_3gnDX  Trump Foundation lacks the certification requi...
#
#                                                    text label
# 2592  in: War Propaganda , World News If it’s not Is...  FAKE
# 2839  0 Add Comment \nIT HAS come to our attention t...  FAKE
# 2302  Russia prevented Spain from diplomatical confl...  FAKE
# 3496  Be the First to Comment! Leave a Reply Click h...  FAKE
# 2248  Donald Trump’s charitable foundation — which h...  REAL

# %%
print("Title:\n")

print(df.loc[0,"title"])

print("\n")

print("News:\n")

print(df.loc[0,"text"])

print("\n")

print("Label : ",df.loc[0,"label"])
# Out:
# Title:
#
# ‘A target on Roe v. Wade ’: Oklahoma bill making it a felony to perform abortions waits for governor’s decision
#
#
# News:
#
# UPDATE: Gov. Fallin vetoed the bill on Friday. Head here for more.
#
# Lawmakers in Oklahoma approved a bill Thursday that would make performing abortions a felony and revoke the medical licenses of most physicians who assist in such procedures.
#
# This sweeping measure, which opponents described as unconstitutional and unprecedented, now heads to Gov. Mary Fallin (R). She will have five days — not including Sunday — to decide whether to sign the bill, veto it or allow it to become law without her signature, according to a spokesman.
#
# “The governor will withhold comment on that bill, as she does on most bills, until she and her staff have had a chance to review it,” Michael McNutt, a spokesman for Fallin, said in an email.
#
# ...

# %%
df["text_length"] = df["text"].apply(len)

# %%
df["text_length"].head()
# Out:
# 0    6677
# 1    4044
# 2    3274
# 3    5316
# 4    2660
# Name: text_length, dtype: int64

# %%
print(df["text_length"].mean())
# Out:
# 4862.717831482691

# %%
df[df["text_length"]==df["text_length"].max()]
# Out:
#              idd                                              title  \
# 3294  eydp4vvCP^  Re: Why Are So Many People Choosing To Leave T...
#
#                                                    text label  text_length
# 3294  Why Are So Many People Choosing To Leave The U...  FAKE       115372

# %%
df.head()
# Out:
#           idd                                              title  \
# 0  Fq+C96tcx+  ‘A target on Roe v. Wade ’: Oklahoma bill maki...
# 1  bHUqK!pgmv  Study: women had to drive 4 times farther afte...
# 2  4Y4Ubf%aTi        Trump, Clinton clash in dueling DC speeches
# 3  _CoY89SJ@K  Grand jury in Texas indicts activists behind P...
# 4  +rJHoRQVLe  As Reproductive Rights Hang In The Balance, De...
#
#                                                 text label  text_length
# 0  UPDATE: Gov. Fallin vetoed the bill on Friday....  REAL         6677
# 1  Ever since Texas laws closed about half of the...  REAL         4044
# 2  Donald Trump and Hillary Clinton, now at the s...  REAL         3274
# 3  A Houston grand jury investigating criminal al...  REAL         5316
# 4  WASHINGTON -- Forty-three years after the Supr...  REAL         2660

# %%
df.to_csv("../data/processed/basic_clean.csv",index=False)

# %%
print("="*50)
print("Dataset Loaded Successfully")
print("Rows :",df.shape[0])
print("Columns :",df.shape[1])
print("Missing Values :",df.isnull().sum().sum())
print("Duplicate Rows :",df.duplicated().sum())
print("="*50)
# Out:
# ...
# Dataset Loaded Successfully
# Rows : 4593
# Columns : 5
# Missing Values : 0
# Duplicate Rows : 0
# ...
